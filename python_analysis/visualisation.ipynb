# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv('../dataset/cleaned_healthcare_data.csv')

# %% [markdown]
# No-show Percentage

# %%
no_show_percentage = (
    df['No_show'].value_counts(normalize=True) * 100
)

print(no_show_percentage)
# Out:
# No_show
# No     79.806561
# Yes    20.193439
# Name: proportion, dtype: float64

# %% [markdown]
# SMS Reminder Impact

# %%
sms_analysis = pd.crosstab(
    df['SMS_received'],
    df['No_show']
)

print(sms_analysis)
# Out:
# No_show          No    Yes
# SMS_received
# 0             62509  12535
# 1             25698   9784

# %% [markdown]
# Plot SMS Reminder Analysis

# %%
sms_analysis.plot(kind='bar')
plt.title('SMS Reminder vs No-show')
plt.xlabel('SMS Received')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Age-wise No-show

# %%
age_groups = pd.cut(
    df['Age'],
    bins=[0,18,40,60,100],
    labels=['Children','Adults','Middle Age','Senior']
)

# %%
age_analysis = pd.crosstab(age_groups, df['No_show'])

print(age_analysis)
# Out:
# No_show        No   Yes
# Age
# Children    19619  5708
# Adults      24442  7375
# Middle Age  24490  5591
# Senior      16752  3003

# %%
age_analysis.plot(kind='bar')
plt.title('Age Group vs No-show')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Gender vs No-show

# %%
gender_analysis = pd.crosstab(
    df['Gender'],
    df['No_show']
)

gender_analysis.plot(
    kind='bar',
    figsize=(6,4)
)

plt.title('Gender vs No-show')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Scholarship Impact

# %%
scholarship_analysis = pd.crosstab(
    df['Scholarship'],
    df['No_show']
)

scholarship_analysis.plot(
    kind='bar',
    figsize=(6,4)
)

plt.title('Scholarship vs No-show')
plt.xlabel('Scholarship')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Hypertension Impact

# %%
hypertension_analysis = pd.crosstab(
    df['Hypertension'],
    df['No_show']
)

hypertension_analysis.plot(
    kind='bar',
    figsize=(6,4)
)

plt.title('Hypertension vs No-show')
plt.xlabel('Hypertension')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Diabetes Impact

# %%
diabetes_analysis = pd.crosstab(
    df['Diabetes'],
    df['No_show']
)

diabetes_analysis.plot(
    kind='bar',
    figsize=(6,4)
)

plt.title('Diabetes vs No-show')
plt.xlabel('Diabetes')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Alcoholism Impact

# %%
alcoholism_analysis = pd.crosstab(
    df['Alcoholism'],
    df['No_show']
)

alcoholism_analysis.plot(
    kind='bar',
    figsize=(6,4)
)

plt.title('Alcoholism vs No-show')
plt.xlabel('Alcoholism')
plt.ylabel('Count')
plt.show()
